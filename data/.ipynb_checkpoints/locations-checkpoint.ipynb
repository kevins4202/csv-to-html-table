# %%
import pandas as pd

# %%
files = ['overall', 'avg_citations', 'avg_h_index', 'total_citations', 'total_h_index']

# %%
for file in files:
    df = pd.read_csv(file + '_ranking.csv')
    
    df['Ranking'] = range(1,df.shape[0]+1)
    cols = [df.columns.tolist()[-1]]+ df.columns.tolist()[:-1]
    
    df = df[cols]
    
    df.to_csv(file + '_ranking.csv', index = False)

# %%
round(answer, 2)

# %%
for file in files:
    df = pd.read_csv(file + '_ranking.csv')
    
    df[df.columns[2]] = df[df.columns[2]].map(lambda x: round(x, 2))
    
    df.to_csv(file + '_ranking.csv', index = False)

# %%
countries = [
    "Greece",  # AUEB
    "Denmark",  # Aalborg University
    "Finland",  # Aalto University
    "Denmark",  # Aarhus University
    "UK",  # Aberystwyth University
    "USA",  # Air Force Institute of Technology
    "Egypt",  # American University in Cairo
    "Lebanon",  # American University of Beirut
    "Israel",  # Ariel University
    "USA",  # Arizona State University
    "USA",  # Auburn University
    "USA",  # Augusta University
    "Australia",  # Australian National University
    "India",  # BITS Pilani
    "India",  # BITS Pilani-Goa
    "Bangladesh",  # BUET
    "China",  # BUPT
    "Romania",  # Babeș-Bolyai University
    "Israel",  # Bar-Ilan University
    "Germany",  # Bauhaus University Weimar
    "China",  # Beihang University
    "Israel",  # Ben-Gurion University of the Negev
    "Germany",  # Bielefeld University
    "Turkey",  # Bilkent University
    "USA",  # Binghamton University
    "UK",  # Birkbeck University of London
    "Italy",  # Bocconi University
    "USA",  # Boise State University
    "USA",  # Boston College
    "USA",  # Boston University
    "Turkey",  # Boğaziçi University
    "USA",  # Brandeis University
    "Germany",  # Brandenburg University of Technology
    "USA",  # Brigham Young University
    "Czech Republic",  # Brno University of Technology
    "USA",  # Brown University
    "UK",  # Brunel University London
    "Germany",  # Bundeswehr University Munich
    "Germany",  # CISPA Helmholtz Center
    "India",  # CMI
    "France",  # CRIStAL
    "USA",  # CUNY
    "Netherlands",  # CWI
    "USA",  # California Institute of Technology
    "UK",  # Cardiff University
    "Canada",  # Carleton University
    "USA",  # Carnegie Mellon University
    "USA",  # Case Western Reserve University
    "Sweden",  # Chalmers/GU
    "Czech Republic",  # Charles University
    "China",  # Chinese Academy of Sciences
    "Hong Kong",  # Chinese University of Hong Kong
    "Thailand",  # Chulalongkorn University
    "Hong Kong",  # City University of Hong Kong
    "UK",  # City University of London
    "USA",  # Claremont Graduate University
    "USA",  # Clemson University
    "USA",  # Cleveland State University
    "USA",  # College of William and Mary
    "USA",  # Colorado School of Mines
    "USA",  # Colorado State University
    "USA",  # Columbia University
    "Canada",  # Concordia University
    "USA",  # Cornell University
    "Cyprus",  # Cyprus University of Technology
    "Czech Republic",  # Czech Technical University
    "India",  # DAIICT
    "Denmark",  # DTU
    "Canada",  # Dalhousie University
    "USA",  # Dartmouth College
    "Philippines",  # De La Salle University
    "USA",  # DePaul University
    "USA",  # Drexel University
    "USA",  # Duke University
    "UK",
    "Switzerland",  # EPFL
    "Switzerland",  # ETH Zurich
    "Canada",  # ETS Montreal
    "France",  # EURECOM
    "France",  # Ecole Normale Superieure
    "France",  # Ecole Normale Superieure de Cachan
    "France",  # Ecole Normale Superieure de Lyon
    "France",  # Ecole Normale Superieure de Rennes
    "USA",  # Emory University
    "Brazil",  # Federal University of Rio Grande
    "USA",  # Florida Atlantic University
    "USA",  # Florida Institute of Technology
    "USA",  # Florida International University
    "USA",  # Florida State University
    "Germany",  # Freie Universitaet Berlin
    "Germany",  # Friedrich Schiller University Jena
    "China",  # Fudan University
    "Turkey",  # Galatasaray University (This might not be a valid entry; Galatasaray is a high school, not a university)
    "USA",  # George Mason University
    "USA",  # George Washington University
    "USA",  # Georgetown University
    "USA",  # Georgia Institute of Technology
    "USA",  # Georgia State University
    "Germany",  # Goethe University Frankfurt
    "UK",  # Goldsmiths University of London
    "Austria",  # Graz University of Technology
    "Hong Kong",  # HKUST
    "Russia",  # HSE University
    "China",  # HUST
    "Turkey",  # Hacettepe University
    "Germany",  # Hamburg University of Technology
    "South Korea",  # Hanyang University
    "China",  # Harbin Institute of Technology
    "USA",  # Harvard University
    "Germany",  # Hasso Plattner Institute
    "Israel",  # Hebrew University of Jerusalem
    "Germany",  # Heidelberg University
    "UK",  # Heriot-Watt University
    "Hong Kong",  # Hong Kong Baptist University
    "Germany",  # Humboldt University of Berlin
    "China",  # Hunan University
    "India",  # IIIT Bangalore
    "India",  # IIIT Delhi
    "India",  # IIIT Hyderabad
    "India",  # IISc Bangalore
    "India",  # IIT (BHU) Varanasi
    "India",  # IIT Bhubaneswar
    "India",  # IIT Bombay
    "India",  # IIT Delhi
    "India",  # IIT Gandhinagar
    "India",  # IIT Goa
    "India",  # IIT Guwahati
    "India",  # IIT Hyderabad
    "India",  # IIT Indore
    "India",  # IIT Jodhpur
    "India",  # IIT Kanpur
    "India",  # IIT Kharagpur
    "India",  # IIT Madras
    "India",  # IIT Mandi
    "India",  # IIT Patna
    "India",  # IIT Roorkee
    "India",  # IIT Ropar
    "Spain",  # IMDEA Networks Institute
    "Spain",  # IMDEA Software Institute
    "India",  # IMSc
    "Poland",  # IPI PAN
    "Iran",  # IPM
    "Austria",  # IST Austria
    "Denmark",  # IT University of Copenhagen
    "USA",  # IUPUI
    "Iran",  # IUST
    "USA",  # Illinois Institute of Technology
    "UK",  # Imperial College London
    "USA",  # Indiana State University
    "USA",  # Indiana University
    "USA",  # Iowa State University
    "Turkey",  # Istanbul Technical University
    "Turkey",  # Izmir Institute of Technology
    "Austria",  # JKU Linz
    "Jordan",  # JUST
    "Germany",  # Jacobs University Bremen
    "USA",  # Johns Hopkins University
    "South Korea",  # KAIST
    "Saudi Arabia",  # KAUST
    "Thailand",  # KMUTNB
    "Sweden",  # KTH Royal Institute of Technology
    "Belgium",  # KU Leuven
    "USA",  # Kansas State University
    "Germany",  # Karlsruhe Institute of Technology
    "Japan",  # Keio University
    "USA",  # Kent State University
    "Saudi Arabia",  # King Abdulaziz University
    "UK",  # King's College London
    "South Korea",  # Korea University
    "Turkey",  # Koç University
    "Japan",  # Kyoto University
    "South Korea",  # Kyung Hee University
    "South Korea",   # Kyungpook National University
    "USA",  # LIU Post
    "Germany",  # LMU Munich
    "Pakistan",  # LUMS
    "UK",  # Lancaster University
    "Lebanon",  # Lebanese American University
    "USA",  # Lehigh University
    "UK",  # Loughborough University
    "USA",  # Louisiana State University
    "USA",  # Louisiana Tech University
    "Sweden",  # Lund University
    "UAE",  # MBZUAI
    "Netherlands",  # Maastricht University
    "Australia",  # Macquarie University
    "Czech Republic",  # Masaryk University
    "UAE",  # Masdar Institute
    "USA",  # Massachusetts Institute of Technology
    "New Zealand",  # Massey University
    "Germany",  # Max Planck Society
    "Canada",  # McGill University
    "Canada",  # McMaster University
    "Canada",  # Memorial University of Newfoundland
    "USA",  # Michigan State University
    "USA",  # Michigan Technological University
    "Turkey",  # Middle East Technical University
    "UK",  # Middlesex University
    "USA",  # Mississippi State University
    "USA",  # Missouri S&T
    "USA",  # Missouri University of Technology (Note: This might be the same as Missouri S&T)
    "Australia",  # Monash University
    "USA",  # Montana State University
    "USA",  # NJIT
    "Norway",  # NTNU
    "Greece",  # NTUA
    "China",  # NWPU
    "China",  # NYU Shanghai
    "China",  # Nanjing University
    "Singapore",  # Nanyang Technological University
    "Taiwan",  # National Cheng Kung University
    "Taiwan",  # National Chiao Tung University
    "India",  # National Institute of Technology Silchar
    "Taiwan",  # National Taiwan University
    "Taiwan",  # National Tsing Hua University
    "Singapore",  # National University of Singapore
    "USA",  # Naval Postgraduate School
    "USA",  # New Mexico State University
    "USA",  # New Mexico Tech
    "USA",  # New York University
    "USA",  # North Carolina State University
    "USA",  # North Dakota State University
    "USA",  # Northeastern University
    "USA",  # Northern Arizona University
    "USA",  # Northwestern University
    "USA",  # Nova Southeastern University
    "USA",  # OHSU
    "USA",  # Oakland University
    "USA",  # Ohio State University
    "USA",  # Ohio University
    "USA",  # Oklahoma State University
    "USA",  # Old Dominion University
    "Canada",  # Ontario Tech University
    "UK",  # Open University UK
    "USA",  # Oregon State University
    "Japan",  # Osaka University
    "South Korea",  # POSTECH
    "Brazil",  # PUC-RIO
    "Brazil",  # PUC-RS
    "Germany",  # Paderborn University
    "China",  # Peking University
    "USA",  # Pennsylvania State University
    "Italy",  # Politecnico di Milano
    "Spain",  # Polytechnic University of Catalonia
    "Canada",  # Polytechnique Montreal
    "USA",  # Portland State University
    "USA",  # Princeton University
    "USA",  # Purdue University
    "Qatar",  # Qatar Computing Research Institute
    "Qatar",  # Qatar University
    "UK",  # Queen Mary University of London
    "UK",  # Queen's University Belfast
    "Australia",  # Queensland University of Technology
    "Canada",  # Queen’s University
    "Australia",  # RMIT University
    "Germany",  # RWTH Aachen
    "Netherlands",  # Radboud University
    "China",  # Renmin University of China
    "USA",  # Rensselaer Polytechnic Institute
    "USA",  # Rice University
    "USA",  # Rochester Institute of Technology
    "UK",  # Royal Holloway University of London
    "Canada",  # Royal Military College of Canada
    "Germany",  # Ruhr-University Bochum
    "Germany",  # Ruhr-Universty Bochum (Seems like a repeated or typo entry, so assigned the same country)
    "USA",  # Rutgers University
    "Canada",  # Ryerson University
    "China",  # SUFE
    "China",  # SUSTech
    "Singapore",  # SUTD
    "Germany",  # Saarland University
    "Turkey",  # Sabancı University
    "Italy",  # Sapienza University of Rome
    "Italy",  # Scuola Superiore Sant'Anna
    "South Korea",  # Seoul National University
    "China",  # Shandong University
    "China",  # Shanghai Jiao Tong University
    "China",  # ShanghaiTech University
    "Iran",  # Sharif University of Technology
    "China",  # Shenzhen University
    "USA",  # Simmons University
    "Canada",  # Simon Fraser University
    "Norway",  # Simula UiB
    "Singapore",  # Singapore Management University
    "China",  # Soochow University
    "India",  # South Asian University
    "USA",  # Southern Methodist University
    "USA",  # Stanford University
    "South Africa",  # Stellenbosch University
    "USA",  # Stevens Institute of Technology
    "USA",  # Stony Brook University
    "China",  # Sun Yat-sen University
    "USA",   # Syracuse University
    "Turkey",  # TOBB ETÜ
    "USA",  # TTI Chicago
    "Germany",  # TU Berlin
    "Germany",  # TU Braunschweig
    "Germany",  # TU Chemnitz
    "Germany",  # TU Clausthal
    "Germany",  # TU Darmstadt
    "Netherlands",  # TU Delft
    "Germany",  # TU Dortmund
    "Germany",  # TU Dresden
    "Netherlands",  # TU Eindhoven
    "Germany",  # TU Freiberg
    "Germany",  # TU Ilmenau
    "Germany",  # TU Kaiserslautern
    "Germany",  # TU Munich
    "Austria",  # TU Wien
    "Finland",  # Tampere University
    "India",  # Tata Inst. of Fundamental Research
    "Israel",  # Technion
    "Israel",  # Tel Aviv University
    "USA",  # Temple University
    "USA",  # Texas A&M University
    "Qatar",  # Texas A&M at Qatar
    "USA",  # Texas State University
    "USA",  # Texas Tech University
    "Hong Kong",  # The Hong Kong Polytechnic University
    "USA",  # The University of Alabama
    "Netherlands",  # Tilburg University
    "Japan",  # Tokyo Institute of Technology
    "China",  # Tongji University
    "USA",  # Towson University
    "China",  # Tsinghua University
    "USA",  # Tufts University
    "USA",  # Tulane University
    "USA",  # UCCS
    "China",  # UESTC
    "Brazil",  # UFF
    "Brazil",  # UFMG
    "Brazil",  # UFMS
    "Brazil",  # UFPE
    "Brazil",  # UFPR
    "Brazil",  # UFRGS
    "Brazil",  # UFRJ
    "Brazil",  # UFU
    "USA",  # UNC - Charlotte
    "Brazil",  # UNICAMP
    "South Korea",  # UNIST
    "Australia",  # UNSW
    "Brazil",  # USP
    "Brazil",  # USP-ICMC
    "China",  # USTC
    "USA",  # Univ. of California - Berkeley
    "USA",  # Univ. of California - Davis
    "USA",  # Univ. of California - Irvine
    "USA",  # Univ. of California - Los Angeles
    "USA",  # Univ. of California - Merced
    "USA",  # Univ. of California - Riverside
    "USA",  # Univ. of California - San Diego
    "USA",  # Univ. of California - Santa Barbara
    "USA",  # Univ. of California - Santa Cruz
    "USA",  # Univ. of Illinois at Urbana-Champaign
    "USA",  # Univ. of Maryland - Baltimore County
    "Argentina",  # Universidad Nacional de Córdoba
    "Spain",  # Universidad Rey Juan Carlos
    "Chile",  # Universidad de Chile
    "Spain",  # Universidad de Zaragoza
    "Colombia",  # Universidad de los Andes
    "Brazil",  # Universidade Federal de Viçosa
    "Portugal",  # Universidade NOVA de Lisboa
    "Brazil",  # Universidade de Brasília
    "Portugal",  # Universidade de Lisboa
    "Ireland",  # University College Dublin
    "UK",  # University College London
    "USA",  # University at Albany - SUNY
    "USA",  # University at Buffalo
    "Spain",  # University of A Coruña
    "UK",  # University of Aberdeen
    "Australia",  # University of Adelaide
    "USA",  # University of Alabama - Birmingham
    "USA",  # University of Alabama - Huntsville
    "Canada",  # University of Alberta
    "Netherlands",  # University of Amsterdam
    "USA",  # University of Arizona
    "USA",  # University of Arkansas
    "USA",  # University of Arkansas - Little Rock
    "Greece",  # University of Athens
    "New Zealand",  # University of Auckland
    "Germany",  # University of Augsburg
    "Germany",  # University of Bamberg
    "UK",  # University of Bath
    "Germany",  # University of Bayreuth
    "Norway",  # University of Bergen
    "Switzerland",  # University of Bern
    "UK",  # University of Birmingham
    "Germany",  # University of Bonn
    "Germany",  # University of Bremen
    "UK",  # University of Bristol
    "Canada",  # University of British Columbia
    "Argentina",  # University of Buenos Aires
    "Canada",  # University of Calgary
    "UK",  # University of Cambridge
    "New Zealand",  # University of Canterbury
    "South Africa",  # University of Cape Town
    "USA",  # University of Central Florida
    "USA",  # University of Chicago
    "USA",  # University of Cincinnati
    "USA",  # University of Colorado - Denver
    "USA",  # University of Colorado Boulder
    "USA",  # University of Connecticut
    "Denmark",  # University of Copenhagen
    "Greece",  # University of Crete
    "USA",  # University of Delaware
    "USA",  # University of Denver
    "Germany",  # University of Duisburg-Essen
    "UK",  # University of Dundee
    "Germany",  # University of Düsseldorf
    "UK",  # University of Edinburgh
    "Germany",  # University of Erlangen–Nuremberg
    "UK",  # University of Essex
    "UK",  # University of Exeter
    "USA",  # University of Florida
    "Germany",  # University of Freiburg
    "USA",  # University of Georgia
    "UK",  # University of Glasgow
    "Netherlands",  # University of Groningen
    "Canada",  # University of Guelph
    "Germany",  # University of Göttingen
    "Israel",  # University of Haifa
    "Germany",  # University of Halle-Wittenberg
    "Germany",  # University of Hamburg
    "Germany",  # University of Hannover
    "USA",  # University of Hawaii at Manoa
    "Finland",  # University of Helsinki
    "Germany",  # University of Hildesheim
    "Hong Kong",  # University of Hong Kong
    "USA",  # University of Houston
    "USA",  # University of Idaho
    "USA",  # University of Illinois at Chicago
    "Austria",  # University of Innsbruck
    "Greece",  # University of Ioannina
    "USA",  # University of Iowa
    "Jordan",  # University of Jordan
    "USA",  # University of Kansas
    "Germany",  # University of Kassel
    "UK",  # University of Kent
    "USA",  # University of Kentucky
    "Germany",  # University of Kiel
    "Austria",  # University of Klagenfurt
    "Germany",  # University of Koblenz-Landau
    "Germany",  # University of Konstanz
    "Italy",  # University of L'Aquila
    "UK",  # University of Leeds
    "Germany",  # University of Leipzig
    "UK",  # University of Liverpool
    "USA",  # University of Louisiana - Lafayette
    "USA",  # University of Louisville
    "Luxembourg",  # University of Luxembourg
    "Germany",  # University of Lübeck
    "Germany",  # University of Magdeburg
    "USA",  # University of Maine
    "Germany",  # University of Mainz
    "Malaysia",  # University of Malaya
    "Malta",  # University of Malta
    "UK",  # University of Manchester
    "Canada",  # University of Manitoba
    "Germany",  # University of Mannheim
    "Germany",  # University of Marburg
    "USA",  # University of Maryland - College Park
    "USA",  # University of Massachusetts Amherst
    "USA",  # University of Massachusetts Boston
    "USA",  # University of Massachusetts Lowell
    "Australia",  # University of Melbourne
    "USA",  # University of Memphis
    "USA",   # University of Miami
    "USA",  # University of Michigan
    "USA",  # University of Michigan-Dearborn
    "USA",  # University of Minnesota
    "USA",  # University of Mississippi
    "USA",  # University of Missouri
    "USA",  # University of Missouri - Kansas City
    "Italy",  # University of Molise
    "Canada",  # University of Montreal
    "Spain",  # University of Murcia
    "Germany",  # University of Münster
    "USA",  # University of Nebraska
    "USA",  # University of Nebraska - Omaha
    "USA",  # University of Nevada
    "USA",  # University of Nevada Las Vegas
    "Canada",  # University of New Brunswick
    "USA",  # University of New Hampshire
    "USA",  # University of New Mexico
    "USA",  # University of New Orleans
    "Australia",  # University of Newcastle
    "Cyprus",  # University of Nicosia
    "USA",  # University of North Carolina
    "USA",  # University of North Texas
    "USA",  # University of Notre Dame
    "UK",  # University of Nottingham
    "USA",  # University of Oklahoma
    "Germany",  # University of Oldenburg
    "USA",  # University of Oregon
    "Germany",  # University of Osnabrück
    "New Zealand",  # University of Otago
    "Canada",  # University of Ottawa
    "UK",  # University of Oxford
    "Germany",  # University of Passau
    "USA",  # University of Pennsylvania
    "Greece",  # University of Piraeus
    "Italy",  # University of Pisa
    "USA",  # University of Pittsburgh
    "Germany",  # University of Potsdam
    "Australia",  # University of Queensland
    "Canada",  # University of Regina
    "USA",  # University of Rochester
    "Germany",  # University of Rostock
    "Italy",  # University of Salerno
    "Austria",  # University of Salzburg
    "Italy",  # University of Sannio
    "Canada",  # University of Saskatchewan
    "UK",  # University of Sheffield
    "Germany",  # University of Siegen
    "USA",  # University of South Carolina
    "USA",  # University of South Florida
    "UK",  # University of Southampton
    "USA",  # University of Southern California
    "USA",  # University of Southern Mississippi
    "UK",  # University of St Andrews
    "Germany",  # University of Stuttgart
    "UK",  # University of Surrey
    "UK",  # University of Sussex
    "Australia",  # University of Sydney
    "Hungary",  # University of Szeged
    "Estonia",  # University of Tartu
    "Australia",  # University of Technology Sydney
    "USA",  # University of Tennessee
    "USA",  # University of Texas - El Paso
    "USA",  # University of Texas at Arlington
    "USA",  # University of Texas at Austin
    "USA",  # University of Texas at Dallas
    "USA",  # University of Texas at San Antonio
    "Japan",  # University of Tokyo
    "Canada",  # University of Toronto
    "Italy",  # University of Trento
    "Germany",  # University of Trier
    "Japan",  # University of Tsukuba
    "USA",  # University of Tulsa
    "Netherlands",  # University of Twente
    "Germany",  # University of Tübingen
    "Germany",  # University of Ulm
    "USA",  # University of Utah
    "USA",  # University of Vermont
    "Canada",  # University of Victoria
    "Austria",  # University of Vienna
    "USA",  # University of Virginia
    "New Zealand",  # University of Waikato
    "Poland",  # University of Warsaw
    "UK",  # University of Warwick
    "USA",  # University of Washington
    "Canada",  # University of Waterloo
    "Australia",  # University of Western Australia
    "Canada",  # University of Windsor
    "USA",  # University of Wisconsin - Madison
    "USA",  # University of Wisconsin - Milwaukee
    "Poland",  # University of Wroclaw
    "Germany",  # University of Wuppertal
    "USA",  # University of Wyoming
    "Germany",  # University of Würzburg
    "UK",  # University of York
    "Switzerland",  # University of Zurich
    "Switzerland",  # Università della Svizzera italiana
    "France",  # Université Jean Monnet
    "Canada",  # Université Laval
    "Canada",  # Université de Sherbrooke
    "Belgium",  # Université libre de Bruxelles
    "Sweden",  # Uppsala University
    "USA",  # Utah State University
    "Netherlands",  # Utrecht University
    "Netherlands",  # VU Amsterdam
    "USA",  # Vanderbilt University
    "New Zealand",  # Victoria University of Wellington
    "USA",  # Virginia Commonwealth University
    "USA",  # Virginia Tech
    "Japan",  # Waseda University
    "USA",  # Washington State University
    "USA",  # Washington University in St. Louis
    "USA",  # Wayne State University
    "Israel",  # Weizmann Institute of Science
    "USA",  # West Virginia University
    "USA",  # Western Michigan University
    "Canada",  # Western University
    "China",  # Westlake University
    "USA",  # Wichita State Unitveristy
    "USA",  # Wichita State University
    "USA",  # Worcester Polytechnic Institute
    "China",  # Wuhan University
    "China",  # Xi'an Jiaotong University
    "China",  # Xidian University
    "USA",  # Yale University
    "South Korea",  # Yonsei University
    "Canada",  # York University
    "Turkey",  # Yıldız Technical University
    "China",  # Zhejiang University
    "Turkey"   # Özyeğin University
]

# %%
colleges = pd.read_csv('/Volumes/mac/CSImpact/csimpact_proj/data/colleges.csv')

# %%
colleges['country'] = countries

# %%
continents = ["Europe",  # AUEB
    "Europe",  # Aalborg University
    "Europe",  # Aalto University
    "Europe",  # Aarhus University
    "Europe",  # Aberystwyth University
    "North America",  # Air Force Institute of Technology
    "Africa",  # American University in Cairo
    "Asia",  # American University of Beirut
    "Asia",  # Ariel University
    "North America",  # Arizona State University
    "North America",  # Auburn University
    "North America",  # Augusta University
    "Oceania",  # Australian National University
    "Asia",  # BITS Pilani
    "Asia",  # BITS Pilani-Goa
    "Asia",  # BUET
    "Asia",  # BUPT
    "Europe",  # Babeș-Bolyai University
    "Asia",  # Bar-Ilan University
    "Europe",  # Bauhaus University Weimar
    "Asia",  # Beihang University
    "Asia",  # Ben-Gurion University of the Negev
    "Europe",  # Bielefeld University
    "Asia",  # Bilkent University
    "North America",  # Binghamton University
    "Europe",  # Birkbeck University of London
    "Europe",  # Bocconi University
    "North America",  # Boise State University
    "North America",  # Boston College
    "North America",  # Boston University
    "Europe",  # Boğaziçi University
    "North America",  # Brandeis University
    "Europe",  # Brandenburg University of Technology
    "North America",  # Brigham Young University
    "Europe",  # Brno University of Technology
    "North America",  # Brown University
    "Europe",  # Brunel University London
    "Europe",  # Bundeswehr University Munich
    "Europe",  # CISPA Helmholtz Center
    "Asia",  # CMI (assuming Chennai Mathematical Institute)
    "Europe",  # CRIStAL
    "North America",  # CUNY
    "Europe",  # CWI
    "North America",  # California Institute of Technology
    "Europe",  # Cardiff University
    "North America",  # Carleton University
    "North America",  # Carnegie Mellon University
    "North America",  # Case Western Reserve University
    "Europe",  # Chalmers/GU
    "Europe",  # Charles University
    "Asia",  # Chinese Academy of Sciences
    "Asia",  # Chinese University of Hong Kong
    "Asia",  # Chulalongkorn University
    "Asia",  # City University of Hong Kong
    "Europe",  # City University of London
    "North America",  # Claremont Graduate University
    "North America",  # Clemson University
    "North America",  # Cleveland State University
    "North America",  # College of William and Mary
    "North America",  # Colorado School of Mines
    "North America",  # Colorado State University
    "North America",  # Columbia University
    "North America",  # Concordia University
    "North America",  # Cornell University
    "Europe",  # Cyprus University of Technology
    "Europe",  # Czech Technical University
    "Asia",  # DAIICT
    "Europe",  # DTU
    "North America",  # Dalhousie University
    "North America",  # Dartmouth College
    "Asia",  # De La Salle University
    "North America",  # DePaul University
    "North America",  # Drexel University
    "North America",  # Duke University
    "Europe",  # Durham University
    "Europe",  # EPFL
    "Europe",  # ETH Zurich
    "North America",  # ETS Montreal
    "Europe",  # EURECOM
    "Europe",  # Ecole Normale Superieure
    "Europe",  # Ecole Normale Superieure de Cachan
    "Europe",  # Ecole Normale Superieure de Lyon
    "Europe",  # Ecole Normale Superieure de Rennes
    "North America",  # Emory University
    "South America",  # Federal University of Rio Grande
    "North America",  # Florida Atlantic University
    "North America",  # Florida Institute of Technology
    "North America",  # Florida International University
    "North America",  # Florida State University
    "Europe",  # Freie Universitaet Berlin
    "Europe",  # Friedrich Schiller University Jena
    "Asia",  # Fudan University
    "Europe",  # Galatasaray University (This might be incorrect as it's not a university but a high school in Turkey)
    "North America",  # George Mason University
    "North America",  # George Washington University
    "North America",  # Georgetown University
    "North America",  # Georgia Institute of Technology
    "North America",  # Georgia State University
    "Europe",  # Goethe University Frankfurt
    "Europe",  # Goldsmiths University of London
    "Europe",  # Graz University of Technology
    "Asia",  # HKUST
    "Europe",  # HSE University
    "Asia",  # HUST
    "Asia",  # Hacettepe University
    "Europe",  # Hamburg University of Technology
    "Asia",  # Hanyang University
    "Asia",  # Harbin Institute of Technology
    "North America",  # Harvard University
    "Europe",  # Hasso Plattner Institute
    "Asia",  # Hebrew University of Jerusalem
    "Europe",  # Heidelberg University
    "Europe",  # Heriot-Watt University
    "Asia",  # Hong Kong Baptist University
    "Europe",  # Humboldt University of Berlin
    "Asia",  # Hunan University
    "Asia",  # IIIT Bangalore
    "Asia",  # IIIT Delhi
    "Asia",  # IIIT Hyderabad
    "Asia",  # IISc Bangalore
    "Asia",  # IIT (BHU) Varanasi
    "Asia",  # IIT Bhubaneswar
    "Asia",  # IIT Bombay
    "Asia",  # IIT Delhi
    "Asia",  # IIT Gandhinagar
    "Asia",  # IIT Goa
    "Asia",  # IIT Guwahati
    "Asia",  # IIT Hyderabad
    "Asia",  # IIT Indore
    "Asia",  # IIT Jodhpur
    "Asia",  # IIT Kanpur
    "Asia",  # IIT Kharagpur
    "Asia",  # IIT Madras
    "Asia",  # IIT Mandi
    "Asia",  # IIT Patna
    "Asia",  # IIT Roorkee
    "Asia",  # IIT Ropar
    "Europe",  # IMDEA Networks Institute
    "Europe",  # IMDEA Software Institute
    "Asia",  # IMSc
    "Europe",  # IPI PAN
    "Asia",  # IPM
    "Europe",  # IST Austria
    "Europe",  # IT University of Copenhagen
    "North America",  # IUPUI
    "Asia",  # IUST
    "North America",  # Illinois Institute of Technology
    "Europe",  # Imperial College London
    "North America",  # Indiana State University
    "North America",  # Indiana University
    "North America",  # Iowa State University
    "Asia",  # Istanbul Technical University
    "Asia",  # Izmir Institute of Technology
    "Europe",  # JKU Linz
    "Asia",  # JUST
    "Europe",  # Jacobs University Bremen
    "North America",  # Johns Hopkins University
    "Asia",  # KAIST
    "Asia",  # KAUST
    "Asia",  # KMUTNB
    "Europe",  # KTH Royal Institute of Technology
    "Europe",  # KU Leuven
    "North America",  # Kansas State University
    "Europe",  # Karlsruhe Institute of Technology
    "Asia",  # Keio University
    "North America",  # Kent State University
    "Asia",  # King Abdulaziz University
    "Europe",  # King's College London
    "Asia",  # Korea University
    "Asia",  # Koç University
    "Asia",  # Kyoto University
    "Asia",  # Kyung Hee University
    "Asia",  # Kyungpook National University
    "North America",  # LIU Post
    "Europe",  # LMU Munich
    "Asia",  # LUMS
    "Europe",  # Lancaster University
    "Asia",  # Lebanese American University
    "North America",  # Lehigh University
    "Europe",  # Loughborough University
    "North America",  # Louisiana State University
    "North America",  # Louisiana Tech University
    "Europe",  # Lund University
    "Asia",  # MBZUAI
    "Europe",  # Maastricht University
    "Australia",  # Macquarie University
    "Europe",  # Masaryk University
    "Asia",  # Masdar Institute
    "North America",  # Massachusetts Institute of Technology
    "Australia",  # Massey University
    "Europe",  # Max Planck Society
    "North America",  # McGill University
    "North America",  # McMaster University
    "North America",  # Memorial University of Newfoundland
    "North America",  # Michigan State University
    "North America",  # Michigan Technological University
    "Asia",  # Middle East Technical University
    "Europe",  # Middlesex University
    "North America",  # Mississippi State University
    "North America",  # Missouri S&T
    "North America",  # Missouri University of Technology (Assuming it's the same as Missouri S&T)
    "Australia",  # Monash University
    "North America",  # Montana State University
    "North America",  # NJIT
    "Europe",  # NTNU
    "Europe",  # NTUA
    "Asia",  # NWPU
    "Asia",  # NYU Shanghai
    "Asia",  # Nanjing University
    "Asia",  # Nanyang Technological University
    "Asia",  # National Cheng Kung University
    "Asia",  # National Chiao Tung University
    "Asia",  # National Institute of Technology Silchar
    "Asia",  # National Taiwan University
    "Asia",  # National Tsing Hua University
    "Asia",  # National University of Singapore
    "North America",  # Naval Postgraduate School
    "North America",  # New Mexico State University
    "North America",  # New Mexico Tech
    "North America",  # New York University
    "North America",  # North Carolina State University
    "North America",  # North Dakota State University
    "North America",  # Northeastern University
    "North America",  # Northern Arizona University
    "North America",  # Northwestern University
    "North America",  # Nova Southeastern University
    "North America",  # OHSU
    "North America",  # Oakland University
    "North America",  # Ohio State University
    "North America",  # Ohio University
    "North America",  # Oklahoma State University
    "North America",  # Old Dominion University
    "North America",  # Ontario Tech University
    "Europe",  # Open University UK
    "North America",  # Oregon State University
    "Asia",  # Osaka University
    "Asia",  # POSTECH
    "South America",  # PUC-RIO
    "South America",  # PUC-RS
    "Europe",  # Paderborn University
    "Asia",  # Peking University
    "North America",  # Pennsylvania State University
    "Europe",  # Politecnico di Milano
    "Europe",  # Polytechnic University of Catalonia
    "North America",  # Polytechnique Montreal
    "North America",  # Portland State University
    "North America",  # Princeton University
    "North America",  # Purdue University
    "Asia",  # Qatar Computing Research Institute
    "Asia",  # Qatar University
    "Europe",  # Queen Mary University of London
    "Europe",  # Queen's University Belfast
    "Australia",  # Queensland University of Technology
    "North America",  # Queen’s University
    "Australia",  # RMIT University
    "Europe",  # RWTH Aachen
    "Europe",  # Radboud University
    "Asia",  # Renmin University of China
    "North America",  # Rensselaer Polytechnic Institute
    "North America",  # Rice University
    "North America",  # Rochester Institute of Technology
    "Europe",  # Royal Holloway University of London
    "North America",  # Royal Military College of Canada
    "Europe",  # Ruhr-University Bochum
    "Europe",  # Ruhr-Universty Bochum (assuming this is a typo and refers to the above university)
    "North America",  # Rutgers University
    "North America",   # Ryerson University
    "Asia",  # SUFE
    "Asia",  # SUSTech
    "Asia",  # SUTD
    "Europe",  # Saarland University
    "Asia",  # Sabancı University
    "Europe",  # Sapienza University of Rome
    "Europe",  # Scuola Superiore Sant'Anna
    "Asia",  # Seoul National University
    "Asia",  # Shandong University
    "Asia",  # Shanghai Jiao Tong University
    "Asia",  # ShanghaiTech University
    "Asia",  # Sharif University of Technology
    "Asia",  # Shenzhen University
    "North America",  # Simmons University
    "North America",  # Simon Fraser University
    "Europe",  # Simula UiB
    "Asia",  # Singapore Management University
    "Asia",  # Soochow University
    "Asia",  # South Asian University
    "North America",  # Southern Methodist University
    "North America",  # Stanford University
    "Africa",  # Stellenbosch University
    "North America",  # Stevens Institute of Technology
    "North America",  # Stony Brook University
    "Asia",  # Sun Yat-sen University
    "North America",  # Syracuse University
    "Asia",  # TOBB ETÜ
    "North America",  # TTI Chicago
    "Europe",  # TU Berlin
    "Europe",  # TU Braunschweig
    "Europe",  # TU Chemnitz
    "Europe",  # TU Clausthal
    "Europe",  # TU Darmstadt
    "Europe",  # TU Delft
    "Europe",  # TU Dortmund
    "Europe",  # TU Dresden
    "Europe",  # TU Eindhoven
    "Europe",  # TU Freiberg
    "Europe",  # TU Ilmenau
    "Europe",  # TU Kaiserslautern
    "Europe",  # TU Munich
    "Europe",  # TU Wien
    "Europe",  # Tampere University
    "Asia",    # Tata Inst. of Fundamental Research
    "Asia",    # Technion
    "Asia",    # Tel Aviv University
    "North America",  # Temple University
    "North America",  # Texas A&M University
    "Asia",    # Texas A&M at Qatar
    "North America",  # Texas State University
    "North America",  # Texas Tech University
    "Asia",    # The Hong Kong Polytechnic University
    "North America",  # The University of Alabama
    "Europe",  # Tilburg University
    "Asia",    # Tokyo Institute of Technology
    "Asia",    # Tongji University
    "North America",  # Towson University
    "Asia",    # Tsinghua University
    "North America",  # Tufts University
    "North America",  # Tulane University
    "North America",  # UCCS
    "Asia",    # UESTC
    "South America",  # UFF
    "South America",  # UFMG
    "South America",  # UFMS
    "South America",  # UFPE
    "South America",  # UFPR
    "South America",  # UFRGS
    "South America",  # UFRJ
    "South America",  # UFU
    "North America",  # UNC - Charlotte
    "South America",  # UNICAMP
    "Asia",    # UNIST
    "Australia",  # UNSW
    "South America",  # USP
    "South America",  # USP-ICMC
    "Asia",    # USTC
    "North America",  # Univ. of California - Berkeley
    "North America",  # Univ. of California - Davis
    "North America",  # Univ. of California - Irvine
    "North America",  # Univ. of California - Los Angeles
    "North America",  # Univ. of California - Merced
    "North America",  # Univ. of California - Riverside
    "North America",  # Univ. of California - San Diego
    "North America",  # Univ. of California - Santa Barbara
    "North America",   # Univ. of California - Santa Cruz
    "North America",  # Univ. of Illinois at Urbana-Champaign
    "North America",  # Univ. of Maryland - Baltimore County
    "South America",  # Universidad Nacional de Córdoba
    "Europe",         # Universidad Rey Juan Carlos
    "South America",  # Universidad de Chile
    "Europe",         # Universidad de Zaragoza
    "South America",  # Universidad de los Andes
    "South America",  # Universidade Federal de Viçosa
    "Europe",         # Universidade NOVA de Lisboa
    "South America",  # Universidade de Brasília
    "Europe",         # Universidade de Lisboa
    "Europe",         # University College Dublin
    "Europe",         # University College London
    "North America",  # University at Albany - SUNY
    "North America",  # University at Buffalo
    "Europe",         # University of A Coruña
    "Europe",         # University of Aberdeen
    "Australia",      # University of Adelaide
    "North America",  # University of Alabama - Birmingham
    "North America",  # University of Alabama - Huntsville
    "North America",  # University of Alberta
    "Europe",         # University of Amsterdam
    "North America",  # University of Arizona
    "North America",  # University of Arkansas
    "North America",  # University of Arkansas - Little Rock
    "Europe",         # University of Athens
    "Australia",      # University of Auckland
    "Europe",         # University of Augsburg
    "Europe",         # University of Bamberg
    "Europe",         # University of Bath
    "Europe",         # University of Bayreuth
    "Europe",         # University of Bergen
    "Europe",         # University of Bern
    "Europe",         # University of Birmingham
    "Europe",         # University of Bonn
    "Europe",         # University of Bremen
    "Europe",         # University of Bristol
    "North America",  # University of British Columbia
    "South America",  # University of Buenos Aires
    "North America",  # University of Calgary
    "Europe",         # University of Cambridge
    "Australia",      # University of Canterbury
    "Africa",         # University of Cape Town
    "North America",  # University of Central Florida
    "North America",  # University of Chicago
    "North America",  # University of Cincinnati
    "North America",  # University of Colorado - Denver
    "North America",  # University of Colorado Boulder
    "North America",  # University of Connecticut
    "Europe",         # University of Copenhagen
    "Europe",         # University of Crete
    "North America",  # University of Delaware
    "North America",  # University of Denver
    "Europe",         # University of Duisburg-Essen
    "Europe",         # University of Dundee
    "Europe",         # University of Düsseldorf
    "Europe",         # University of Edinburgh
    "Europe",         # University of Erlangen–Nuremberg
    "Europe",         # University of Essex
    "Europe",         # University of Exeter
    "North America",  # University of Florida
    "Europe",         # University of Freiburg
    "North America",  # University of Georgia
    "Europe",         # University of Glasgow
    "Europe",         # University of Groningen
    "North America",  # University of Guelph
    "Europe",         # University of Göttingen
    "Asia",           # University of Haifa
    "Europe",         # University of Halle-Wittenberg
    "Europe",         # University of Hamburg
    "Europe",         # University of Hannover
    "North America",  # University of Hawaii at Manoa
    "Europe",         # University of Helsinki
    "Europe",         # University of Hildesheim
    "Asia",           # University of Hong Kong
    "North America",  # University of Houston
    "North America",
              # University of Idaho
              "North America",  # University of Illinois at Chicago
    "Europe",         # University of Innsbruck
    "Europe",         # University of Ioannina
    "North America",  # University of Iowa
    "Asia",           # University of Jordan
    "North America",  # University of Kansas
    "Europe",         # University of Kassel
    "Europe",         # University of Kent
    "North America",  # University of Kentucky
    "Europe",         # University of Kiel
    "Europe",         # University of Klagenfurt
    "Europe",         # University of Koblenz-Landau
    "Europe",         # University of Konstanz
    "Europe",         # University of L'Aquila
    "Europe",         # University of Leeds
    "Europe",         # University of Leipzig
    "Europe",         # University of Liverpool
    "North America",  # University of Louisiana - Lafayette
    "North America",  # University of Louisville
    "Europe",         # University of Luxembourg
    "Europe",         # University of Lübeck
    "Europe",         # University of Magdeburg
    "North America",  # University of Maine
    "Europe",         # University of Mainz
    "Asia",           # University of Malaya
    "Europe",         # University of Malta
    "Europe",         # University of Manchester
    "North America",  # University of Manitoba
    "Europe",         # University of Mannheim
    "Europe",         # University of Marburg
    "North America",  # University of Maryland - College Park
    "North America",  # University of Massachusetts Amherst
    "North America",  # University of Massachusetts Boston
    "North America",  # University of Massachusetts Lowell
    "Australia",      # University of Melbourne
    "North America",  # University of Memphis
    "North America",  # University of Miami
    "North America",  # University of Michigan
    "North America",  # University of Michigan-Dearborn
    "North America",  # University of Minnesota
    "North America",  # University of Mississippi
    "North America",  # University of Missouri
    "North America",  # University of Missouri - Kansas City
    "Europe",         # University of Molise
    "North America",  # University of Montreal
    "Europe",         # University of Murcia
    "Europe",         # University of Münster
    "North America",  # University of Nebraska
    "North America",  # University of Nebraska - Omaha
    "North America",  # University of Nevada
    "North America",  # University of Nevada Las Vegas
    "North America",  # University of New Brunswick
    "North America",  # University of New Hampshire
    "North America",  # University of New Mexico
    "North America",  # University of New Orleans
    "Australia",      # University of Newcastle
    "Europe",         # University of Nicosia
    "North America",  # University of North Carolina
    "North America",  # University of North Texas
    "North America",  # University of Notre Dame
    "Europe",         # University of Nottingham
    "North America",  # University of Oklahoma
    "Europe",         # University of Oldenburg
    "North America",  # University of Oregon
    "Europe",         # University of Osnabrück
    "Australia",      # University of Otago
    "North America",  # University of Ottawa
    "Europe",         # University of Oxford
    "Europe",         # University of Passau
    "North America",  # University of Pennsylvania
    "Europe",         # University of Piraeus
    "Europe",         # University of Pisa
    "North America",  # University of Pittsburgh
    "Europe",         # University of Potsdam
    "Australia",      # University of Queensland
    "North America",  # University of Regina
    "North America",  # University of Rochester
    "Europe",         # University of Rostock
    "Europe",         # University of Salerno
    "Europe",         # University of Salzburg
    "Europe",         # University of Sannio
    "North America",  # University of Saskatchewan
    "Europe",         # University of Sheffield
    "Europe",         # University of Siegen
    "North America",  # University of South Carolina
    "North America",  # University of South Florida
    "Europe",         # University of Southampton
    "North America",  # University of Southern California
    "North America",  # University of Southern Mississippi
    "Europe",         # University of St Andrews
    "Europe",         # University of Stuttgart
    "Europe",         # University of Surrey
    "Europe",         # University of Sussex
    "Australia",      # University of Sydney
    "Europe",         # University of Szeged
    "Europe",         # University of Tartu
    "Australia",      # University of Technology Sydney
    "North America",  # University of Tennessee
    "North America",  # University of Texas - El Paso
    "North America",  # University of Texas at Arlington
    "North America",  # University of Texas at Austin
    "North America",  # University of Texas at Dallas
    "North America",  # University of Texas at San Antonio
    "Asia",           # University of Tokyo
    "North America",  # University of Toronto
    "Europe",         # University of Trento
    "Europe",         # University of Trier
    "Asia",           # University of Tsukuba
    "North America",  # University of Tulsa
    "Europe",         # University of Twente
    "Europe",         # University of Tübingen
    "Europe",         # University of Ulm
    "North America",  # University of Utah
    "North America",  # University of Vermont
    "North America",  # University of Victoria
    "Europe",         # University of Vienna
    "North America",  # University of Virginia
    "Australia",      # University of Waikato
    "Europe",         # University of Warsaw
    "Europe",         # University of Warwick
    "North America",  # University of Washington
    "North America",  # University of Waterloo
    "Australia",      # University of Western Australia
    "North America",  # University of Windsor
    "North America",  # University of Wisconsin - Madison
    "North America",  # University of Wisconsin - Milwaukee
    "Europe",         # University of Wroclaw
    "Europe",         # University of Wuppertal
    "North America",  # University of Wyoming
    "Europe",         # University of Würzburg
    "Europe",         # University of York
    "Europe",         # University of Zurich
    "Europe",         # Università della Svizzera italiana
    "Europe",         # Université Jean Monnet
    "North America",  # Université Laval
    "North America",  # Université de Sherbrooke
    "Europe",         # Université libre de Bruxelles
    "Europe",         # Uppsala University
    "North America",  # Utah State University
    "Europe",         # Utrecht University
    "Europe",         # VU Amsterdam
    "North America",  # Vanderbilt University
    "Australia",      # Victoria University of Wellington
    "North America",  # Virginia Commonwealth University
    "North America",  # Virginia Tech
    "Asia",           # Waseda University
    "North America",  # Washington State University
    "North America",  # Washington University in St. Louis
    "North America",  # Wayne State University
    "Asia",           # Weizmann Institute of Science
    "North America",  # West Virginia University
    "North America",  # Western Michigan University
    "North America",  # Western University
    "Asia",           # Westlake University
    "North America",  # Wichita State Unitveristy
    "North America",  # Wichita State University
    "North America",  # Worcester Polytechnic Institute
    "Asia",           # Wuhan University
    "Asia",           # Xi'an Jiaotong University
    "Asia",           # Xidian University
    "North America",  # Yale University
    "Asia",           # Yonsei University
    "North America",  # York University
    "Europe",         # Yıldız Technical University
    "Asia",           # Zhejiang University
    "Europe"          # Özyeğin University
             ]

# %%
colleges['continent'] = continents

# %%
colleges.to_csv('/Volumes/mac/CSImpact/csimpact_proj/data/colleges.csv', index = False)

# %%
colleges
# Out:
#                          college      country      continent
# 0                           AUEB       Greece         Europe
# 1             Aalborg University      Denmark         Europe
# 2               Aalto University      Finland         Europe
# 3              Aarhus University      Denmark         Europe
# 4         Aberystwyth University           UK         Europe
# ..                           ...          ...            ...
# 591            Yonsei University  South Korea           Asia
# 592              York University       Canada  North America
# 593  Yıldız Technical University       Turkey         Europe
# 594          Zhejiang University        China           Asia
# 595           Özyeğin University       Turkey         Europe
#
# [596 rows x 3 columns]

# %%
colleges_i = colleges.set_index('college')

# %%
colleges_i
# Out:
#                                  country      continent
# college
# AUEB                              Greece         Europe
# Aalborg University               Denmark         Europe
# Aalto University                 Finland         Europe
# Aarhus University                Denmark         Europe
# Aberystwyth University                UK         Europe
# ...                                  ...            ...
# Yonsei University            South Korea           Asia
# York University                   Canada  North America
# Yıldız Technical University       Turkey         Europe
# Zhejiang University                China           Asia
# Özyeğin University                Turkey         Europe
#
# [596 rows x 2 columns]

# %%
for file in files:
    df = pd.read_csv(file + '_ranking.csv')
    
    count = []
    cont = []
    
    for i in range(len(colleges_i.index)):
        curr = df.iat[i,1]
        cont.append(colleges_i.loc[curr]['continent'])
        count.append(colleges_i.loc[curr]['country'])
        
    df['country'] = count
    df['continent'] = cont
    
    df.to_csv(file + '_ranking.csv', index = False)
